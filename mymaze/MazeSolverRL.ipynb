# %%
import tensorflow as tf
from tensorflow import keras
from Maze import Maze
from time import time
import numpy as np

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.01)
huber_loss = keras.losses.Huber()
action_probs_history = []
critic_value_history = []
rewards_history = []

# %%
def train_reinforcement_network(n_neurons, maze_height=5, maze_width=10, gamma=0.8, eps=np.finfo(np.float32).eps.item()):
    """
    Training algorithm for the maze
    :param gamma: The discount value for past rewards
    :param eps: The epsilon value (small number!0)
    :param n_neurons: The number of neurons for the common layer
    :param maze_height: The starting maze height (increases by 1 each training run)
    :param maze_width: The starting maze width (increases by 1 each training run)
    :return:
    """
    if maze_height == 'random' and maze_width == 'random':
        import random
        maze_height = random.randint(5,30)
        maze_width = random.randint(5,30)

    inputs = keras.layers.Input(shape=(Maze.N_INPUTS,))

    common = keras.layers.Dense(n_neurons, activation="relu")(inputs)
    action = keras.layers.Dense(Maze.N_INPUTS, activation="softmax")(common)
    critic = keras.layers.Dense(1)(common)

    # The full RL model with the action layer and the critic
    model = keras.Model(inputs=inputs, outputs=[action, critic])

    running_reward = 0


    mazes_complete = 0
    while True:
        # Reward for the current run
        episode_reward = 0

        # Create a maze and display it!
        my_maze = Maze(maze_height, maze_width)
        my_maze.create_maze()
        my_maze.print_maze()

        state: list

        maze_height += 1
        maze_width += 1

        # Loop through the steps of one maze
        start_time = time()
        iteration = 0
        while not my_maze.is_maze_complete():
            iteration += 1
            print(f"Iteration: {iteration}", my_maze.player.r, my_maze.player.c)
            with tf.GradientTape() as tape:
                state = tf.convert_to_tensor([int(x) for x in my_maze.get_maze_options()])
                state = tf.expand_dims(state, 0)

                action_probs, critic_value = model(state)
                critic_value_history.append(critic_value[0, 0])

                action = np.random.choice(Maze.N_INPUTS, p=np.squeeze(action_probs))
                action_probs_history.append(tf.math.log(action_probs[0, action]))

                reward = my_maze.take_action(action)
                print("Reward: {:.2f}, Mazes complete: {}".format(reward, mazes_complete))
                rewards_history.append(reward)
                episode_reward += reward


                running_reward = 0.05 * episode_reward + (1 - 0.05) * running_reward

                # Calculate expected value from rewards
                returns = []
                discounted_sum = 0
                for r in rewards_history[::-1]:
                    discounted_sum = r + gamma * discounted_sum
                    returns.insert(0, discounted_sum)

                # Normalize
                returns = np.array(returns)
                returns = (returns - np.mean(returns)) / (np.std(returns) + eps)
                returns = returns.tolist()

                # Calculating loss values to update our network
                history = zip(action_probs_history, critic_value_history, returns)
                actor_losses = []
                critic_losses = []
                for log_prob, value, ret in history:
                    diff = ret - value
                    actor_losses.append(-log_prob * diff)  # actor loss

                    critic_losses.append(huber_loss(tf.expand_dims(value, 0), tf.expand_dims(ret, 0)))

                # Backpropagation
                loss_value = sum(actor_losses) + sum(critic_losses)
                grads = tape.gradient(loss_value, model.trainable_variables)
                optimizer.apply_gradients(zip(grads, model.trainable_variables))
        print(f'Training time: {time()-start_time}')
        mazes_complete += 1

# %%
train_reinforcement_network(n_neurons=5, maze_height=4, maze_width=4)
# Out:
# █ ▢ █ █
# █     █
# █   █ █
# █ △ █ █
#
#
#
# Iteration: 1 3 1
# Reward: 0.33, Mazes complete: 0
# Iteration: 2 3 1
# Reward: 0.33, Mazes complete: 0
# Iteration: 3 3 1
# Reward: 0.33, Mazes complete: 0
# Iteration: 4 3 1
# Reward: 0.33, Mazes complete: 0
# Iteration: 5 3 1
# Reward: 0.33, Mazes complete: 0
# Iteration: 6 3 1
# Reward: 0.50, Mazes complete: 0
# Iteration: 7 2 1
# Reward: 0.50, Mazes complete: 0
# Iteration: 8 2 1
# Reward: 0.50, Mazes complete: 0
# Iteration: 9 2 1
# Reward: 0.50, Mazes complete: 0
# Iteration: 10 2 1
# Reward: 0.33, Mazes complete: 0
# Iteration:
4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 173 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 174 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 175 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 176 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 177 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 178 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 179 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 180 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 181 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 182 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 183 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 184 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 185 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 186 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 187 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 188 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 189 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 190 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 191 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 192 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 193 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 194 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 195 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 196 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 197 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 198 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 199 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 200 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 201 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 202 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 203 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 204 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 205 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 206 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 207 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 208 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 209 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 210 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 211 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 212 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 213 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 214 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 215 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 216 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 217 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 218 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 219 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 220 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 221 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 222 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 223 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 224 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 225 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 226 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 227 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 228 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 229 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 230 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 231 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 232 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 233 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 234 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 235 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 236 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 237 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 238 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 239 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 240 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 241 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 242 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 243 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 244 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 245 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 246 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 247 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 248 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 249 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 250 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 251 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 252 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 253 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 254 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 255 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 256 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 257 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 258 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 259 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 260 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 261 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 262 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 263 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 264 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 265 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 266 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 267 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 268 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 269 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 270 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 271 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 272 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 273 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 274 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 275 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 276 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 277 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 278 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 279 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 280 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 281 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 282 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 283 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 284 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 285 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 286 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 287 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 288 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 289 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 290 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 291 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 292 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 293 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 294 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 295 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 296 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 297 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 298 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 299 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 300 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 301 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 302 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 303 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 304 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 305 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 306 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 307 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 308 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 309 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 310 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 311 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 312 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 313 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 314 5 2
# Reward: 0.20, Mazes complete: 3
# Iteration: 315 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 316 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 317 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 318 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 319 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 320 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 321 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 322 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 323 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 324 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 325 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 326 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 327 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 328 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 329 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 330 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 331 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 332 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 333 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 334 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 335 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 336 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 337 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 338 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 339 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 340 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 341 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 342 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 343 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 344 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 345 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 346 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 347 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 348 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 349 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 350 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 351 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 352 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 353 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 354 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 355 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 356 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 357 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 358 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 359 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 360 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 361 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 362 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 363 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 364 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 365 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 366 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 367 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 368 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 369 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 370 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 371 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 372 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 373 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 374 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 375 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 376 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 377 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 378 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 379 5 2
# Reward: 0.20, Mazes complete: 3
# Iteration: 380 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 381 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 382 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 383 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 384 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 385 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 386 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 387 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 388 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 389 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 390 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 391 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 392 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 393 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 394 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 395 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 396 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 397 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 398 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 399 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 400 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 401 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 402 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 403 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 404 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 405 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 406 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 407 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 408 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 409 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 410 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 411 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 412 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 413 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 414 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 415 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 416 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 417 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 418 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 419 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 420 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 421 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 422 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 423 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 424 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 425 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 426 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 427 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 428 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 429 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 430 4 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 431 5 1
# Reward: 0.20, Mazes complete: 3
# Iteration: 432 5 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 433 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 434 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 435 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 436 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 437 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 438 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 439 4 1
# Reward: 0.25, Mazes complete: 3
# Iteration: 440 4 1
# Reward: 0.25, Mazes complete: 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 train_reinforcement_network(n_neurons=5, maze_height=4, maze_width=4)
#
# Input In [37], in train_reinforcement_network(n_neurons, maze_height, maze_width, gamma, eps)
#      84     diff = ret - value
#      85     actor_losses.append(-log_prob * diff)  # actor loss
# ---> 87     critic_losses.append(huber_loss(tf.expand_dims(value, 0), tf.expand_dims(ret, 0)))
#      89 # Backpropagation
#      90 loss_value = sum(actor_losses) + sum(critic_losses)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\array_ops.py:443, in expand_dims_v2(input, axis, name)
#     376 @tf_export("expand_dims", v1=[])
#     377 @dispatch.add_dispatch_support
#     378 def expand_dims_v2(input, axis, name=None):
#     379   """Returns a tensor with a length 1 axis inserted at index `axis`.
#     380
#     381   Given a tensor `input`, this operation inserts a dimension of length 1 at the
#    (...)
#     441     InvalidArgumentError: If `axis` is out of range `[-(D+1), D]`.
#     442   """
# --> 443   return gen_array_ops.expand_dims(input, axis, name)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:2339, in expand_dims(input, axis, name)
#    2337 if tld.is_eager:
#    2338   try:
# -> 2339     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    2340       _ctx, "ExpandDims", name, input, axis)
#    2341     return _result
#    2342   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
